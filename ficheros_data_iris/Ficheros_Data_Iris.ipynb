# %% [markdown]
# # <center><u>Explorando la Data Iris</u></center>
# ## Situando directorio

# %%
import os
os.getcwd()
os.chdir("C:\\Users\\Usuario\\Desktop\\L.P.II")

# %% [markdown]
# ## Lectura de Datos

# %%
import pandas as pd
data= pd.read_csv('iris.txt', names=["longitud_del_sépalo(cm)","ancho_del_sépalo(cm)","longitud_del_pétalo(cm)","ancho_de_pétalo(cm)","clase"])
data
# Out:
#      longitud_del_sépalo(cm)  ancho_del_sépalo(cm)  longitud_del_pétalo(cm)  \
# 0                        5.1                   3.5                      1.4
# 1                        4.9                   3.0                      1.4
# 2                        4.7                   3.2                      1.3
# 3                        4.6                   3.1                      1.5
# 4                        5.0                   3.6                      1.4
# ..                       ...                   ...                      ...
# 145                      6.7                   3.0                      5.2
# 146                      6.3                   2.5                      5.0
# 147                      6.5                   3.0                      5.2
# 148                      6.2                   3.4                      5.4
# 149                      5.9                   3.0                      5.1
#
#      ancho_de_pétalo(cm)           clase
# ...

# %% [markdown]
# ## Descripción general de datos

# %%
data.describe()
# Out:
#        longitud_del_sépalo(cm)  ancho_del_sépalo(cm)  longitud_del_pétalo(cm)  \
# count               150.000000            150.000000               150.000000
# mean                  5.843333              3.054000                 3.758667
# std                   0.828066              0.433594                 1.764420
# min                   4.300000              2.000000                 1.000000
# 25%                   5.100000              2.800000                 1.600000
# 50%                   5.800000              3.000000                 4.350000
# 75%                   6.400000              3.300000                 5.100000
# max                   7.900000              4.400000                 6.900000
#
#        ancho_de_pétalo(cm)
# count           150.000000
# mean              1.198667
# std               0.763161
# min               0.100000
# 25%               0.300000
# 50%               1.300000
# 75%               1.800000
# max               2.500000

# %% [markdown]
# ## Descripciónes extra

# %%
#Ordenan los datos según "longitud de sépalo"
print(data.sort_values(by='longitud_del_sépalo(cm)'))
# Out:
#      longitud_del_sépalo(cm)  ancho_del_sépalo(cm)  longitud_del_pétalo(cm)  \
# 13                       4.3                   3.0                      1.1
# 42                       4.4                   3.2                      1.3
# 38                       4.4                   3.0                      1.3
# 8                        4.4                   2.9                      1.4
# 41                       4.5                   2.3                      1.3
# ..                       ...                   ...                      ...
# 122                      7.7                   2.8                      6.7
# 118                      7.7                   2.6                      6.9
# 117                      7.7                   3.8                      6.7
# 135                      7.7                   3.0                      6.1
# 131                      7.9                   3.8                      6.4
#
#      ancho_de_pétalo(cm)           clase
# ...

# %%
#filtrando los datos cuya "longitud_del_sépalo(cm)" sea mayor a 5cm
data.loc[data["longitud_del_sépalo(cm)"] > 5.0]
# Out:
#      longitud_del_sépalo(cm)  ancho_del_sépalo(cm)  longitud_del_pétalo(cm)  \
# 0                        5.1                   3.5                      1.4
# 5                        5.4                   3.9                      1.7
# 10                       5.4                   3.7                      1.5
# 14                       5.8                   4.0                      1.2
# 15                       5.7                   4.4                      1.5
# ..                       ...                   ...                      ...
# 145                      6.7                   3.0                      5.2
# 146                      6.3                   2.5                      5.0
# 147                      6.5                   3.0                      5.2
# 148                      6.2                   3.4                      5.4
# 149                      5.9                   3.0                      5.1
#
#      ancho_de_pétalo(cm)           clase
# ...

# %%
#filtrando columnas
data.loc[:50, ['longitud_del_sépalo(cm)', 'longitud_del_pétalo(cm)','clase']]
# Out:
#     longitud_del_sépalo(cm)  longitud_del_pétalo(cm)            clase
# 0                       5.1                      1.4      Iris-setosa
# 1                       4.9                      1.4      Iris-setosa
# 2                       4.7                      1.3      Iris-setosa
# 3                       4.6                      1.5      Iris-setosa
# 4                       5.0                      1.4      Iris-setosa
# 5                       5.4                      1.7      Iris-setosa
# 6                       4.6                      1.4      Iris-setosa
# 7                       5.0                      1.5      Iris-setosa
# 8                       4.4                      1.4      Iris-setosa
# 9                       4.9                      1.5      Iris-setosa
# 10                      5.4                      1.5      Iris-setosa
# 11                      4.8                      1.6      Iris-setosa
# ...
